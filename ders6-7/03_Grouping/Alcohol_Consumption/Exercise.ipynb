# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarized as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
df.groupby('continent')['beer_servings'].mean().sort_values(ascending=False)
# Out:
# continent
# EU    193.777778
# SA    175.083333
# OC     89.687500
# AF     61.471698
# AS     37.045455
# Name: beer_servings, dtype: float64

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
df.groupby('continent')['wine_servings'].describe().T # %10
# Out:
# continent          AF          AS          EU         OC          SA
# count       53.000000   44.000000   45.000000   16.00000   12.000000
# mean        16.264151    9.068182  142.222222   35.62500   62.416667
# std         38.846419   21.667034   97.421738   64.55579   88.620189
# min          0.000000    0.000000    0.000000    0.00000    1.000000
# 25%          1.000000    0.000000   59.000000    1.00000    3.000000
# 50%          2.000000    1.000000  128.000000    8.50000   12.000000
# 75%         13.000000    8.000000  195.000000   23.25000   98.500000
# max        233.000000  123.000000  370.000000  212.00000  221.000000

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
df.groupby('continent').mean()
# Out:
# /var/folders/t5/5f7r8lfn3654qmfbpb3gbyx80000gn/T/ipykernel_70783/2361145216.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('continent').mean()
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
df.groupby('continent').sum()
# Out:
# /var/folders/t5/5f7r8lfn3654qmfbpb3gbyx80000gn/T/ipykernel_70783/3203133957.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('continent').sum()
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  3258              866            862
# AS                  1630             2677            399
# EU                  8720             5965           6400
# OC                  1435              935            570
# SA                  2101             1377            749
#
#            total_litres_of_pure_alcohol
# continent
# AF                                159.4
# AS                                 95.5
# EU                                387.8
# OC                                 54.1
# SA                                 75.7

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %% [markdown]
# df.total_litres_of_pure_alcohol = df['total_litres_of_pure_alcohol']

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
df.groupby('continent').agg(['mean','min','max','std','median'])
# Out:
# /var/folders/t5/5f7r8lfn3654qmfbpb3gbyx80000gn/T/ipykernel_70783/2322134348.py:1: FutureWarning: ['country'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('continent').agg(['mean','min','max','std','median'])
#           beer_servings                            spirit_servings           \
#                    mean min  max        std median            mean min  max
# continent
# AF            61.471698   0  376  80.557816   32.0       16.339623   0  152
# AS            37.045455   0  247  49.469725   17.5       60.840909   0  326
# EU           193.777778   0  361  99.631569  219.0      132.555556   0  373
# OC            89.687500   0  306  96.641412   52.5       58.437500   0  254
# SA           175.083333  93  333  65.242845  162.5      114.750000  25  302
#
#                             wine_servings                             \
# ...
