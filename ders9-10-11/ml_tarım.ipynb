# %%
import numpy as np 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('main.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    N    P    K    pH    EC    OC     S    Zn    Fe    Cu    Mn  \
# 0           0  138  8.6  560  7.46  0.62  0.70   5.9  0.24  0.31  0.77  8.71
# 1           1  213  7.5  338  7.62  0.75  1.06  25.4  0.30  0.86  1.54  2.89
# 2           2  163  9.6  718  7.59  0.51  1.11  14.3  0.30  0.86  1.57  2.70
# 3           3  157  6.8  475  7.64  0.58  0.94  26.0  0.34  0.54  1.53  2.65
# 4           4  270  9.9  444  7.63  0.40  0.86  11.8  0.25  0.76  1.69  2.43
#
#       B  verim
# 0  0.11     58
# 1  2.29     68
# 2  2.03     75
# 3  1.82     58
# 4  2.26     89

# %%
df = df.drop(df.columns[0],axis=1)

# %%
df.head()
# Out:
#      N    P    K    pH    EC    OC     S    Zn    Fe    Cu    Mn     B  verim
# 0  138  8.6  560  7.46  0.62  0.70   5.9  0.24  0.31  0.77  8.71  0.11     58
# 1  213  7.5  338  7.62  0.75  1.06  25.4  0.30  0.86  1.54  2.89  2.29     68
# 2  163  9.6  718  7.59  0.51  1.11  14.3  0.30  0.86  1.57  2.70  2.03     75
# 3  157  6.8  475  7.64  0.58  0.94  26.0  0.34  0.54  1.53  2.65  1.82     58
# 4  270  9.9  444  7.63  0.40  0.86  11.8  0.25  0.76  1.69  2.43  2.26     89

# %% [markdown]
# # Bağımlı Değişken (tahmin edilecek değer)

# %%
y = df['verim']

# %% [markdown]
# # Bağımsız değişken

# %%
# Parametreler, sonucu değiştiren etkenler

# %%
X = df.drop('verim',axis=1)
X.head()
# Out:
#      N    P    K    pH    EC    OC     S    Zn    Fe    Cu    Mn     B
# 0  138  8.6  560  7.46  0.62  0.70   5.9  0.24  0.31  0.77  8.71  0.11
# 1  213  7.5  338  7.62  0.75  1.06  25.4  0.30  0.86  1.54  2.89  2.29
# 2  163  9.6  718  7.59  0.51  1.11  14.3  0.30  0.86  1.57  2.70  2.03
# 3  157  6.8  475  7.64  0.58  0.94  26.0  0.34  0.54  1.53  2.65  1.82
# 4  270  9.9  444  7.63  0.40  0.86  11.8  0.25  0.76  1.69  2.43  2.26

# %% [markdown]
# # Train test split

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Assuming you have your data in the form of features (X) and labels (y)
# X is a 2D array containing features, and y is a 1D array containing labels

# Split the data into training and testing sets
# By default, the split ratio is 75% training and 25% testing
# You can adjust the 'test_size' parameter to change the split ratio
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Now, you can use X_train and y_train to train your model
# And use X_test and y_test to evaluate its performance on unseen data

# %%
X_train.shape, y_train.shape
# Out:
# ((660, 12), (660,))

# %%
X_test.shape, y_test.shape
# Out:
# ((220, 12), (220,))

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Doğrusal regresyon modelini oluştur
model = LinearRegression()

# Modeli eğit
model.fit(X_train, y_train)

# Modeli kullanarak tahmin yap
y_pred = model.predict(X_test)

# Modelin performansını değerlendir
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Ortalama Kare Hata (Mean Squared Error):", mse)
print("R-kare (R-squared) değeri:", r2)
# Out:
# Ortalama Kare Hata (Mean Squared Error): 210.68152704921144
# R-kare (R-squared) değeri: -0.05638209292423335

# %%
sonuc = pd.DataFrame([y_pred,y_test]).T

# %%
sonuc
# Out:
#              0     1
# 0    74.797888  52.0
# 1    74.822279  73.0
# 2    76.618246  58.0
# 3    75.500716  74.0
# 4    73.427313  79.0
# ..         ...   ...
# 215  74.519308  67.0
# 216  74.585000  61.0
# 217  74.807221  80.0
# 218  75.605439  74.0
# 219  76.217895  60.0
#
# [220 rows x 2 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score


def evaluate_linear_regression(X, y):
    model_name = "Doğrusal Regresyon"
    # Veri kümesini eğitim ve test olarak ayıralım
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Doğrusal regresyon modelini oluştur
    model = LinearRegression()

    # Modeli eğit
    model.fit(X_train, y_train)

    # Test verileri için tahmin yap
    y_pred_test = model.predict(X_test)

    # Ortalama Karesel Hata (Mean Squared Error)
    mse = mean_squared_error(y_test, y_pred_test)

    # R-kare (Coefficient of Determination)
    r2 = r2_score(y_test, y_pred_test)

    # Raporu yazdır
    print("------ Model Başarısı ------")
    print("Model:", model_name)
    print("Ortalama Karesel Hata (MSE):", mse)
    print("R-kare (R-squared) Değeri:", r2)

    # Tahmin edilen ve gerçek değerleri pandas DataFrame olarak oluşturalım
    result_df = pd.DataFrame({'Tahmin Edilen': y_pred_test.flatten(), 'Gerçek Değerler': y_test.values.flatten()})
    print("\n------ Gerçek Değerler ile Tahmin Edilen Değerler ------")
    print(result_df)

# Örnek kullanım:
# evaluate_linear_regression(X, y)

# %%
evaluate_linear_regression(X,y)
# Out:
# ------ Model Başarısı ------
# Model: Doğrusal Regresyon
# Ortalama Karesel Hata (MSE): 211.65230189023492
# R-kare (R-squared) Değeri: -0.02561534426320078
#
# ------ Gerçek Değerler ile Tahmin Edilen Değerler ------
#      Tahmin Edilen  Gerçek Değerler
# 0        74.561665               52
# 1        74.084414               73
# 2        75.897368               58
# 3        75.531994               74
# 4        72.673583               79
# ..             ...              ...
# 259      74.060237               79
# 260      74.720235               81
# 261      72.663035               84
# 262      74.686762               91
# 263      75.557558               96
#
# [264 rows x 2 columns]

# %% [markdown]
# # KNN

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score


def evaluate_knn_regression(X, y, n_neighbors=5):
    model_name = "K-En Yakın Komşu (KNN)"
    # Veri kümesini eğitim ve test olarak ayıralım
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # K-En Yakın Komşu modelini oluştur
    model = KNeighborsRegressor(n_neighbors=n_neighbors)

    # Modeli eğit
    model.fit(X_train, y_train)

    # Test verileri için tahmin yap
    y_pred_test = model.predict(X_test)

    # Ortalama Mutlak Hata (Mean Absolute Error)
    mae = mean_absolute_error(y_test, y_pred_test)

    # R-kare (Coefficient of Determination)
    r2 = r2_score(y_test, y_pred_test)

    # Raporu yazdır
    print("------ Model Başarısı ------")
    print("Model:", model_name)
    print("Ortalama Mutlak Hata (MAE):", mae)
    print("R-kare (R-squared) Değeri:", r2)

    # Tahmin edilen ve gerçek değerleri pandas DataFrame olarak oluşturalım
    result_df = pd.DataFrame({'Tahmin Edilen': y_pred_test.flatten(), 'Gerçek Değerler': y_test.values.flatten()})
    print("\n------ Gerçek Değerler ile Tahmin Edilen Değerler ------")
    print(result_df)

# Örnek kullanım:
# evaluate_knn_regression(X, y, n_neighbors=5)

# %%
evaluate_knn_regression(X, y, n_neighbors=5)
# Out:
# ------ Model Başarısı ------
# Model: K-En Yakın Komşu (KNN)
# Ortalama Mutlak Hata (MAE): 13.715151515151517
# R-kare (R-squared) Değeri: -0.23597312808213267
#
# ------ Gerçek Değerler ile Tahmin Edilen Değerler ------
#      Tahmin Edilen  Gerçek Değerler
# 0             77.6               52
# 1             74.2               73
# 2             68.8               58
# 3             85.6               74
# 4             77.8               79
# ..             ...              ...
# 259           69.0               79
# 260           69.4               81
# 261           72.2               84
# 262           67.6               91
# 263           67.8               96
#
# [264 rows x 2 columns]

# %% [markdown]
# # SVR

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error, r2_score

def evaluate_svm_regression(X, y, kernel='linear'):
    model_name = "Destek Vektör Makineleri (SVM)"
    # Veri kümesini eğitim ve test olarak ayıralım
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # SVM modelini oluştur
    model = SVR(kernel=kernel)

    # Modeli eğit
    model.fit(X_train, y_train.ravel())

    # Test verileri için tahmin yap
    y_pred_test = model.predict(X_test)

    # Ortalama Mutlak Yüzde Hata (Mean Absolute Percentage Error)
    mape = mean_absolute_percentage_error(y_test, y_pred_test)

    # R-kare (Coefficient of Determination)
    r2 = r2_score(y_test, y_pred_test)

    # Raporu yazdır
    print("------ Model Başarısı ------")
    print("Model:", model_name)
    print("Ortalama Mutlak Yüzde Hata (MAPE):", mape)
    print("R-kare (R-squared) Değeri:", r2)

    # Tahmin edilen ve gerçek değerleri pandas DataFrame olarak oluşturalım
    result_df = pd.DataFrame({'Tahmin Edilen': y_pred_test, 'Gerçek Değerler': y_test.values.flatten()})
    print("\n------ Gerçek Değerler ile Tahmin Edilen Değerler ------")
    print(result_df)

# Örnek kullanım:
# evaluate_svm_regression(X, y, kernel='linear')

# %%
evaluate_svm_regression(X,y)
# Out:
# ------ Model Başarısı ------
# Model: Destek Vektör Makineleri (SVM)
# Ortalama Mutlak Yüzde Hata (MAPE): 0.18145342451810634
# R-kare (R-squared) Değeri: -0.050834867362300695
#
# ------ Gerçek Değerler ile Tahmin Edilen Değerler ------
#      Tahmin Edilen  Gerçek Değerler
# 0        76.720531               52
# 1        75.187027               73
# 2        75.624516               58
# 3        77.229290               74
# 4        73.414939               79
# ..             ...              ...
# 259      73.753929               79
# 260      74.072051               81
# 261      73.845331               84
# 262      74.915469               91
# 263      76.317712               96
#
# [264 rows x 2 columns]

# %% [markdown]
# # Artificial Neural Network

# %%
import numpy as np
import pandas as pd
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score


def evaluate_ann_regression(X, y):
    model_name = "Yapay Sinir Ağları (ANN)"
    # Veri kümesini eğitim ve test olarak ayıralım
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Yapay Sinir Ağı modelini oluştur
    model = MLPRegressor(hidden_layer_sizes=(100,), activation='relu', solver='adam', random_state=42)

    # Modeli eğit
    model.fit(X_train, y_train.ravel())

    # Test verileri için tahmin yap
    y_pred_test = model.predict(X_test)

    # Ortalama Mutlak Hata (Mean Absolute Error)
    mae = mean_absolute_error(y_test, y_pred_test)

    # R-kare (Coefficient of Determination)
    r2 = r2_score(y_test, y_pred_test)

    # Raporu yazdır
    print("------ Model Başarısı ------")
    print("Model:", model_name)
    print("Ortalama Mutlak Hata (MAE):", mae)
    print("R-kare (R-squared) Değeri:", r2)

    # Tahmin edilen ve gerçek değerleri pandas DataFrame olarak oluşturalım
    result_df = pd.DataFrame({'Tahmin Edilen': y_pred_test, 'Gerçek Değerler': y_test.values.flatten()})
    print("\n------ Gerçek Değerler ile Tahmin Edilen Değerler ------")
    print(result_df)

# Örnek kullanım:
# evaluate_ann_regression(X, y)

# %%
evaluate_ann_regression(X,y)
# Out:
# ------ Model Başarısı ------
# Model: Yapay Sinir Ağları (ANN)
# Ortalama Mutlak Hata (MAE): 14.354480969049016
# R-kare (R-squared) Değeri: -0.40763308501922735
#
# ------ Gerçek Değerler ile Tahmin Edilen Değerler ------
#      Tahmin Edilen  Gerçek Değerler
# 0        71.468459               52
# 1        59.628955               73
# 2        63.639496               58
# 3        74.524241               74
# 4        53.279185               79
# ..             ...              ...
# 259      60.183983               79
# 260      64.177753               81
# 261      73.040918               84
# 262      71.885737               91
# 263      71.872609               96
#
# [264 rows x 2 columns]

# %% [markdown]
# # CART

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score


def evaluate_cart_regression(X, y):
    model_name = "CART (Sınıflandırma ve Regresyon Ağaçları)"
    # Veri kümesini eğitim ve test olarak ayıralım
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # CART modelini oluştur
    model = DecisionTreeRegressor(random_state=42)

    # Modeli eğit
    model.fit(X_train, y_train)

    # Test verileri için tahmin yap
    y_pred_test = model.predict(X_test)

    # Ortalama Mutlak Hata (Mean Absolute Error)
    mae = mean_absolute_error(y_test, y_pred_test)

    # R-kare (Coefficient of Determination)
    r2 = r2_score(y_test, y_pred_test)

    # Raporu yazdır
    print("------ Model Başarısı ------")
    print("Model:", model_name)
    print("Ortalama Mutlak Hata (MAE):", mae)
    print("R-kare (R-squared) Değeri:", r2)

    # Tahmin edilen ve gerçek değerleri pandas DataFrame olarak oluşturalım
    result_df = pd.DataFrame({'Tahmin Edilen': y_pred_test, 'Gerçek Değerler': y_test.values.flatten()})
    print("\n------ Gerçek Değerler ile Tahmin Edilen Değerler ------")
    print(result_df)

# Örnek kullanım:
# evaluate_cart_regression(X, y)

# %%
evaluate_cart_regression(X,y)
# Out:
# ------ Model Başarısı ------
# Model: CART (Sınıflandırma ve Regresyon Ağaçları)
# Ortalama Mutlak Hata (MAE): 15.132575757575758
# R-kare (R-squared) Değeri: -0.6645354315292273
#
# ------ Gerçek Değerler ile Tahmin Edilen Değerler ------
#      Tahmin Edilen  Gerçek Değerler
# 0             50.0               52
# 1             70.0               73
# 2             91.0               58
# 3             95.0               74
# 4             58.0               79
# ..             ...              ...
# 259           60.0               79
# 260           50.0               81
# 261           58.0               84
# 262           57.0               91
# 263           61.0               96
#
# [264 rows x 2 columns]

# %% [markdown]
# # Random Forest

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score



def evaluate_random_forest_regression(X, y):
    model_name = "Random Forest"
    # Veri kümesini eğitim ve test olarak ayıralım
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Random Forest modelini oluştur
    model = RandomForestRegressor(n_estimators=100, random_state=42)

    # Modeli eğit
    model.fit(X_train, y_train.ravel())

    # Test verileri için tahmin yap
    y_pred_test = model.predict(X_test)

    # Ortalama Mutlak Hata (Mean Absolute Error)
    mae = mean_absolute_error(y_test, y_pred_test)

    # R-kare (Coefficient of Determination)
    r2 = r2_score(y_test, y_pred_test)

    # Raporu yazdır
    print("------ Model Başarısı ------")
    print("Model:", model_name)
    print("Ortalama Mutlak Hata (MAE):", mae)
    print("R-kare (R-squared) Değeri:", r2)

    # Tahmin edilen ve gerçek değerleri pandas DataFrame olarak oluşturalım
    result_df = pd.DataFrame({'Tahmin Edilen': y_pred_test, 'Gerçek Değerler': y_test.values.flatten()})
    print("\n------ Gerçek Değerler ile Tahmin Edilen Değerler ------")
    print(result_df)

# Örnek kullanım:
# evaluate_random_forest_regression(X, y)

# %%
evaluate_random_forest_regression(X,y)
# Out:
# ------ Model Başarısı ------
# Model: Random Forest
# Ortalama Mutlak Hata (MAE): 12.529583333333335
# R-kare (R-squared) Değeri: -0.028373173969970855
#
# ------ Gerçek Değerler ile Tahmin Edilen Değerler ------
#      Tahmin Edilen  Gerçek Değerler
# 0            69.37               52
# 1            73.40               73
# 2            77.61               58
# 3            80.48               74
# 4            74.44               79
# ..             ...              ...
# 259          71.40               79
# 260          75.27               81
# 261          70.06               84
# 262          75.01               91
# 263          74.12               96
#
# [264 rows x 2 columns]

# %% [markdown]
# # Bonus - XGboost

# %%
! pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /Users/suleakarsu/anaconda3/lib/python3.10/site-packages (1.7.6)
# Requirement already satisfied: scipy in /Users/suleakarsu/anaconda3/lib/python3.10/site-packages (from xgboost) (1.10.0)
# Requirement already satisfied: numpy in /Users/suleakarsu/anaconda3/lib/python3.10/site-packages (from xgboost) (1.23.5)

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score


def evaluate_xgboost_regression(X, y):
    model_name = "XGBoost"
    # Veri kümesini eğitim ve test olarak ayıralım
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # XGBoost modelini oluştur
    model = xgb.XGBRegressor( random_state=42)

    # Modeli eğit
    model.fit(X_train, y_train)

    # Test verileri için tahmin yap
    y_pred_test = model.predict(X_test)

    # Ortalama Mutlak Hata (Mean Absolute Error)
    mae = mean_absolute_error(y_test, y_pred_test)

    # R-kare (Coefficient of Determination)
    r2 = r2_score(y_test, y_pred_test)

    # Raporu yazdır
    print("------ Model Başarısı ------")
    print("Model:", model_name)
    print("Ortalama Mutlak Hata (MAE):", mae)
    print("R-kare (R-squared) Değeri:", r2)

    # Tahmin edilen ve gerçek değerleri pandas DataFrame olarak oluşturalım
    result_df = pd.DataFrame({'Tahmin Edilen': y_pred_test, 'Gerçek Değerler': y_test.values.flatten()})
    print("\n------ Gerçek Değerler ile Tahmin Edilen Değerler ------")
    print(result_df)

# Örnek kullanım:
# evaluate_xgboost_regression(X, y)

# %%
evaluate_xgboost_regression(X,y)
# Out:
# ------ Model Başarısı ------
# Model: XGBoost
# Ortalama Mutlak Hata (MAE): 13.29717325441765
# R-kare (R-squared) Değeri: -0.21142827471291104
#
# ------ Gerçek Değerler ile Tahmin Edilen Değerler ------
#      Tahmin Edilen  Gerçek Değerler
# 0        69.982658               52
# 1        65.634758               73
# 2        73.791245               58
# 3        78.648193               74
# 4        72.072601               79
# ..             ...              ...
# 259      70.092583               79
# 260      80.099976               81
# 261      60.024815               84
# 262      76.109222               91
# 263      65.218010               96
#
# [264 rows x 2 columns]

# %% [markdown]
# # Sum Up

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score

def evaluate_regression_algorithms(X, y):
    algorithms = [
        ("Doğrusal Regresyon", LinearRegression()),
        ("K-En Yakın Komşu (KNN)", KNeighborsRegressor(n_neighbors=5)),
        ("Destek Vektör Makineleri (SVM)", SVR(kernel='linear')),
        ("CART (Sınıflandırma ve Regresyon Ağaçları)", DecisionTreeRegressor(random_state=42)),
        ("Random Forest", RandomForestRegressor(n_estimators=100, random_state=42)),
        ("XGBoost", xgb.XGBRegressor(objective='reg:squarederror', random_state=42))
    ]

    results = []  # Tüm algoritmaların sonuçlarını depolamak için boş bir liste oluşturuyoruz.

    # Veri kümesini eğitim ve test olarak ayıralım
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    for name, model in algorithms:
        # Modeli eğit
        model.fit(X_train, y_train.ravel())

        # Test verileri için tahmin yap
        y_pred_test = model.predict(X_test)

        # Ortalama Mutlak Hata (Mean Absolute Error)
        mae = mean_absolute_error(y_test.values.flatten(), y_pred_test)

        # R-kare (Coefficient of Determination)
        r2 = r2_score(y_test.values.flatten(), y_pred_test)

        # Sonuçları listeye ekle
        results.append((name, mae, r2))

        # Raporu yazdır
        print("-"*50)
        print("Model:", name)
        print("Ortalama Mutlak Hata (MAE):", mae)
        print("R-kare (R-squared) Değeri:", r2)
    return results
# Örnek kullanım:
results = evaluate_regression_algorithms(X, y)
# Out:
# --------------------------------------------------
# Model: Doğrusal Regresyon
# Ortalama Mutlak Hata (MAE): 12.485766365762272
# R-kare (R-squared) Değeri: -0.02561534426320078
# --------------------------------------------------
# Model: K-En Yakın Komşu (KNN)
# Ortalama Mutlak Hata (MAE): 13.715151515151517
# R-kare (R-squared) Değeri: -0.23597312808213267
# --------------------------------------------------
# Model: Destek Vektör Makineleri (SVM)
# Ortalama Mutlak Hata (MAE): 12.748597901200414
# R-kare (R-squared) Değeri: -0.050834867362300695
# --------------------------------------------------
# Model: CART (Sınıflandırma ve Regresyon Ağaçları)
# Ortalama Mutlak Hata (MAE): 15.132575757575758
# R-kare (R-squared) Değeri: -0.6645354315292273
# --------------------------------------------------
# Model: Random Forest
# Ortalama Mutlak Hata (MAE): 12.529583333333335
# R-kare (R-squared) Değeri: -0.028373173969970855
# --------------------------------------------------
# Model: XGBoost
# Ortalama Mutlak Hata (MAE): 13.29717325441765
# R-kare (R-squared) Değeri: -0.21142827471291104

# %%
# MAE değeri en küçük olan algoritmayı seçiyoruz
best_algorithm = min(results, key=lambda x: x[1])
print("*"*50)

print("En İyi Model:", best_algorithm[0])
print("En İyi Model Ortalama Mutlak Hata (MAE):", best_algorithm[1])
print("En İyi Model R-kare (R-squared) Değeri:", best_algorithm[2])
# Out:
# **************************************************
# En İyi Model: Doğrusal Regresyon
# En İyi Model Ortalama Mutlak Hata (MAE): 12.485766365762272
# En İyi Model R-kare (R-squared) Değeri: -0.02561534426320078
